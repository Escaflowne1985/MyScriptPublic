# %% [markdown]
# # Funnel_Funnel_sort_ascending
# - 【Python数据可视化漏斗图AI教程】上升效果漏斗图
# - 金字塔上升效果漏斗图

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker

c = (
    Funnel()
    .add(
        "data",
        [list(z) for z in zip(Faker.choose(), Faker.values())],
        sort_="ascending",
        label_opts=opts.LabelOpts(position="inside"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel_sort_ascending"))
#     .render("funnel_sort_ascending.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d77c54e47ac1426a9d034ff811256a2b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d77c54e47ac1426a9d034ff811256a2b = echarts.init(
#                     document.getElementById('d77c54e47ac1426a9d034ff811256a2b'), 'white', {renderer: 'canvas'});
#                 var option_d77c54e47ac1426a9d034ff811256a2b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Funnel_Funnel_base
# - 【Python数据可视化漏斗图AI教程】基础漏斗图
# - 基础漏斗图

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker

c = (
    Funnel()
    .add("data", [list(z) for z in zip(Faker.choose(), Faker.values())])
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel_base"))
#     .render("funnel_base.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f466cd17898a49f6b32e56312aa4c152" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f466cd17898a49f6b32e56312aa4c152 = echarts.init(
#                     document.getElementById('f466cd17898a49f6b32e56312aa4c152'), 'white', {renderer: 'canvas'});
#                 var option_f466cd17898a49f6b32e56312aa4c152 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Funnel_Funnel_chart
# - 【Python数据可视化漏斗图AI教程】文字内嵌漏斗图
# - 文字嵌入到漏斗图

# %%
import pyecharts.options as opts
from pyecharts.charts import Funnel

x_data = ["char1", "char2", "char3", "char4", "char5"]
y_data = [100, 80, 60, 40, 20]

data = [[x_data[i], y_data[i]] for i in range(len(x_data))]

c = (
    Funnel(init_opts=opts.InitOpts())
    .add(
        series_name="",
        data_pair=data,
        gap=2,
        tooltip_opts=opts.TooltipOpts(trigger="item", formatter="{a} <br/>{b} : {c}%"),
        label_opts=opts.LabelOpts(is_show=True, position="inside"),
        itemstyle_opts=opts.ItemStyleOpts(border_color="#fff", border_width=1),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel_chart", subtitle="Funnel_chart"))
#     .render("funnel_chart.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e2434d9c44b14f099eefa3669c3ae052" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e2434d9c44b14f099eefa3669c3ae052 = echarts.init(
#                     document.getElementById('e2434d9c44b14f099eefa3669c3ae052'), 'white', {renderer: 'canvas'});
#                 var option_e2434d9c44b14f099eefa3669c3ae052 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Funnel_Funnel_label_inside
# - 【Python数据可视化漏斗图AI教程】缩放的仪表盘类别内嵌漏斗图
# - 类别内嵌漏斗图

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker


c = (
    Funnel()
    .add(
        "data",
        [list(z) for z in zip(Faker.choose(), Faker.values())],
        label_opts=opts.LabelOpts(position="inside"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel_label_inside"))
#     .render("funnel_label_inside.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7462821ecf7a4d14a63473588976fca8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7462821ecf7a4d14a63473588976fca8 = echarts.init(
#                     document.getElementById('7462821ecf7a4d14a63473588976fca8'), 'white', {renderer: 'canvas'});
#                 var option_7462821ecf7a4d14a63473588976fca8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
