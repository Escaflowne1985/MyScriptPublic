# %% [markdown]
# # Dataset_pie
# - 【Python数据集可视化AI教程】可视化饼图数据集
# - 将已有的数据进行饼图可视化

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie

c = (
    Pie()
    .add_dataset(
        source=[
            ["product", "2012", "2013", "2014", "2015", "2016", "2017"],
            ["Matcha Latte", 41.1, 30.4, 65.1, 53.3, 83.8, 98.7],
            ["Milk Tea", 86.5, 92.1, 85.7, 83.1, 73.4, 55.1],
            ["Cheese Cocoa", 24.1, 67.2, 79.5, 86.4, 65.2, 82.5],
            ["Walnut Brownie", 55.2, 67.1, 69.2, 72.4, 53.9, 39.1],
        ]
    )
    .add(
        series_name="Matcha Latte",
        data_pair=[],
        radius=60,
        center=["25%", "30%"],
        encode={"itemName": "product", "value": "2012"},
    )
    .add(
        series_name="Milk Tea",
        data_pair=[],
        radius=60,
        center=["75%", "30%"],
        encode={"itemName": "product", "value": "2013"},
    )
    .add(
        series_name="Cheese Cocoa",
        data_pair=[],
        radius=60,
        center=["25%", "75%"],
        encode={"itemName": "product", "value": "2014"},
    )
    .add(
        series_name="Walnut Brownie",
        data_pair=[],
        radius=60,
        center=["75%", "75%"],
        encode={"itemName": "product", "value": "2015"},
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Dataset simple pie example"),
        legend_opts=opts.LegendOpts(pos_left="30%", pos_top="2%"),
    )
#     .render("dataset_pie.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="34681bbbb0334951b8b1e3b4a0d59c07" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_34681bbbb0334951b8b1e3b4a0d59c07 = echarts.init(
#                     document.getElementById('34681bbbb0334951b8b1e3b4a0d59c07'), 'white', {renderer: 'canvas'});
#                 var option_34681bbbb0334951b8b1e3b4a0d59c07 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "Matcha Latte",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "25%",
#                 "30%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2012"
#             }
#         },
#         {
#             "type": "pie",
#             "name": "Milk Tea",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "75%",
#                 "30%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2013"
#             }
#         },
#         {
#             "type": "pie",
#             "name": "Cheese Cocoa",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "25%",
#                 "75%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2014"
#             }
#         },
#         {
#             "type": "pie",
#             "name": "Walnut Brownie",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "75%",
#                 "75%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2015"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Matcha Latte",
#                 "Milk Tea",
#                 "Cheese Cocoa",
#                 "Walnut Brownie"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "30%",
#             "top": "2%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "dataset": {
#         "source": [
#             [
#                 "product",
#                 "2012",
#                 "2013",
#                 "2014",
#                 "2015",
#                 "2016",
#                 "2017"
#             ],
#             [
#                 "Matcha Latte",
#                 41.1,
#                 30.4,
#                 65.1,
#                 53.3,
#                 83.8,
#                 98.7
#             ],
#             [
#                 "Milk Tea",
#                 86.5,
#                 92.1,
#                 85.7,
#                 83.1,
#                 73.4,
#                 55.1
#             ],
#             [
#                 "Cheese Cocoa",
#                 24.1,
#                 67.2,
#                 79.5,
#                 86.4,
#                 65.2,
#                 82.5
#             ],
#             [
#                 "Walnut Brownie",
#                 55.2,
#                 67.1,
#                 69.2,
#                 72.4,
#                 53.9,
#                 39.1
#             ]
#         ]
#     },
#     "title": [
#         {
#             "text": "Dataset simple pie example",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_34681bbbb0334951b8b1e3b4a0d59c07.setOption(option_34681bbbb0334951b8b1e3b4a0d59c07);
#         });
#     </script>

# %% [markdown]
# # Dataset_Dataset_bar_0
# - 【Python数据集可视化AI教程】可视化柱状图数据集(纵向)
# - 将已有的数据进行柱状图可视化

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

c = (
    Bar()
    .add_dataset(
        source=[
            ["product", "2015", "2016", "2017"],
            ["Matcha Latte", 43.3, 85.8, 93.7],
            ["Milk Tea", 83.1, 73.4, 55.1],
            ["Cheese Cocoa", 86.4, 65.2, 82.5],
            ["Walnut Brownie", 72.4, 53.9, 39.1],
        ]
    )
    .add_yaxis(series_name="2015", yaxis_data=[])
    .add_yaxis(series_name="2016", yaxis_data=[])
    .add_yaxis(series_name="2017", yaxis_data=[])
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Dataset simple bar example"),
        xaxis_opts=opts.AxisOpts(type_="category"),
    )
#     .render("dataset_bar_0.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="63d7a3048f3e4e829b86003193db8f3d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_63d7a3048f3e4e829b86003193db8f3d = echarts.init(
#                     document.getElementById('63d7a3048f3e4e829b86003193db8f3d'), 'white', {renderer: 'canvas'});
#                 var option_63d7a3048f3e4e829b86003193db8f3d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "2015",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "2016",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "2017",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2015",
#                 "2016",
#                 "2017"
#             ],
#             "selected": {
#                 "2015": true,
#                 "2016": true,
#                 "2017": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "dataset": {
#         "source": [
#             [
#                 "product",
#                 "2015",
#                 "2016",
#                 "2017"
#             ],
#             [
#                 "Matcha Latte",
#                 43.3,
#                 85.8,
#                 93.7
#             ],
#             [
#                 "Milk Tea",
#                 83.1,
#                 73.4,
#                 55.1
#             ],
#             [
#                 "Cheese Cocoa",
#                 86.4,
#                 65.2,
#                 82.5
#             ],
#             [
#                 "Walnut Brownie",
#                 72.4,
#                 53.9,
#                 39.1
#             ]
#         ]
#     },
#     "title": [
#         {
#             "text": "Dataset simple bar example",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_63d7a3048f3e4e829b86003193db8f3d.setOption(option_63d7a3048f3e4e829b86003193db8f3d);
#         });
#     </script>

# %% [markdown]
# # Dataset_Dataset_bar_1
# - 【Python数据集可视化AI教程】可视化柱状图数据集(横向)
# - 将已有的数据进行柱状图可视化

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

c = (
    Bar()
    .add_dataset(
        source=[
            ["score", "amount", "product"],
            [89.3, 58212, "Matcha Latte"],
            [57.1, 78254, "Milk Tea"],
            [74.4, 41032, "Cheese Cocoa"],
            [50.1, 12755, "Cheese Brownie"],
            [89.7, 20145, "Matcha Cocoa"],
            [68.1, 79146, "Tea"],
            [19.6, 91852, "Orange Juice"],
            [10.6, 101852, "Lemon Juice"],
            [32.7, 20112, "Walnut Brownie"],
        ]
    )
    .add_yaxis(
        series_name="",
        yaxis_data=[],
        encode={"x": "amount", "y": "product"},
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Dataset normal bar example"),
        xaxis_opts=opts.AxisOpts(name="amount"),
        yaxis_opts=opts.AxisOpts(type_="category"),
        visualmap_opts=opts.VisualMapOpts(
            orient="horizontal",
            pos_left="center",
            min_=10,
            max_=100,
            range_text=["High Score", "Low Score"],
            dimension=0,
            range_color=["#D7DA8B", "#E15457"],
        ),
    )
#     .render("dataset_bar_1.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c799a950879d45708e9bd7d4ad68a03f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c799a950879d45708e9bd7d4ad68a03f = echarts.init(
#                     document.getElementById('c799a950879d45708e9bd7d4ad68a03f'), 'white', {renderer: 'canvas'});
#                 var option_c799a950879d45708e9bd7d4ad68a03f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "x": "amount",
#                 "y": "product"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "name": "amount",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "dataset": {
#         "source": [
#             [
#                 "score",
#                 "amount",
#                 "product"
#             ],
#             [
#                 89.3,
#                 58212,
#                 "Matcha Latte"
#             ],
#             [
#                 57.1,
#                 78254,
#                 "Milk Tea"
#             ],
#             [
#                 74.4,
#                 41032,
#                 "Cheese Cocoa"
#             ],
#             [
#                 50.1,
#                 12755,
#                 "Cheese Brownie"
#             ],
#             [
#                 89.7,
#                 20145,
#                 "Matcha Cocoa"
#             ],
#             [
#                 68.1,
#                 79146,
#                 "Tea"
#             ],
#             [
#                 19.6,
#                 91852,
#                 "Orange Juice"
#             ],
#             [
#                 10.6,
#                 101852,
#                 "Lemon Juice"
#             ],
#             [
#                 32.7,
#                 20112,
#                 "Walnut Brownie"
#             ]
#         ]
#     },
#     "title": [
#         {
#             "text": "Dataset normal bar example",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 10,
#         "max": 100,
#         "text": [
#             "High Score",
#             "Low Score"
#         ],
#         "inRange": {
#             "color": [
#                 "#D7DA8B",
#                 "#E15457"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "horizontal",
#         "left": "center",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_c799a950879d45708e9bd7d4ad68a03f.setOption(option_c799a950879d45708e9bd7d4ad68a03f);
#         });
#     </script>

# %% [markdown]
# # Dataset_Dataset_professional_scatter
# - 【Python数据集可视化AI教程】可视化散点图数据集
# - 将已有的数据进行散点图可视化

# %%
import json

from pyecharts import options as opts
from pyecharts.charts import Grid, Scatter

with open("data/life-expectancy-table.json", "r", encoding="utf-8") as f:
    j = json.load(f)

l1_1 = (
    Scatter()
    .add_dataset(
        dimensions=[
            "Income",
            "Life Expectancy",
            "Population",
            "Country",
            {"name": "Year", "type": "ordinal"},
        ],
        source=j,
    )
    .add_yaxis(
        series_name="",
        y_axis=[],
        symbol_size=2.5,
        xaxis_index=0,
        yaxis_index=0,
        encode={"x": "Income", "y": "Life Expectancy", "tooltip": [0, 1, 2, 3, 4]},
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(
            type_="value",
            grid_index=0,
            name="Income",
            axislabel_opts=opts.LabelOpts(rotate=50, interval=0),
        ),
        yaxis_opts=opts.AxisOpts(type_="value", grid_index=0, name="Life Expectancy"),
        title_opts=opts.TitleOpts(title="Encode and Matrix"),
    )
)

l1_2 = (
    Scatter()
    .add_dataset()
    .add_yaxis(
        series_name="",
        y_axis=[],
        symbol_size=2.5,
        xaxis_index=1,
        yaxis_index=1,
        encode={"x": "Country", "y": "Income", "tooltip": [0, 1, 2, 3, 4]},
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(
            type_="category",
            grid_index=1,
            name="Country",
            boundary_gap=False,
            axislabel_opts=opts.LabelOpts(rotate=50, interval=0),
        ),
        yaxis_opts=opts.AxisOpts(type_="value", grid_index=1, name="Income"),
    )
)

l2_1 = (
    Scatter()
    .add_dataset()
    .add_yaxis(
        series_name="",
        y_axis=[],
        symbol_size=2.5,
        xaxis_index=2,
        yaxis_index=2,
        encode={"x": "Income", "y": "Population", "tooltip": [0, 1, 2, 3, 4]},
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(
            type_="value",
            grid_index=2,
            name="Income",
            axislabel_opts=opts.LabelOpts(rotate=50, interval=0),
        ),
        yaxis_opts=opts.AxisOpts(type_="value", grid_index=2, name="Population"),
    )
)

l2_2 = (
    Scatter()
    .add_dataset()
    .add_yaxis(
        series_name="",
        y_axis=[],
        symbol_size=2.5,
        xaxis_index=3,
        yaxis_index=3,
        encode={"x": "Life Expectancy", "y": "Population", "tooltip": [0, 1, 2, 3, 4]},
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(
            type_="value",
            grid_index=3,
            name="Life Expectancy",
            axislabel_opts=opts.LabelOpts(rotate=50, interval=0),
        ),
        yaxis_opts=opts.AxisOpts(type_="value", grid_index=3, name="Population"),
    )
)

grid = (
    Grid(init_opts=opts.InitOpts(width="900px", height="600px"))
    .add(
        chart=l1_1,
        grid_opts=opts.GridOpts(pos_right="57%", pos_bottom="57%"),
        grid_index=0,
    )
    .add(
        chart=l1_2,
        grid_opts=opts.GridOpts(pos_left="57%", pos_bottom="57%"),
        grid_index=1,
    )
    .add(
        chart=l2_1,
        grid_opts=opts.GridOpts(pos_right="57%", pos_top="57%"),
        grid_index=2,
    )
    .add(
        chart=l2_2, grid_opts=opts.GridOpts(pos_left="57%", pos_top="57%"), grid_index=3
    )
#     .render("dataset_professional_scatter.html")
)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="80e43a08fbfe465fb8b44531c76d63e8" style="width:900px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_80e43a08fbfe465fb8b44531c76d63e8 = echarts.init(
#                     document.getElementById('80e43a08fbfe465fb8b44531c76d63e8'), 'white', {renderer: 'canvas'});
#                 var option_80e43a08fbfe465fb8b44531c76d63e8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 2.5,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "x": "Income",
#                 "y": "Life Expectancy",
#                 "tooltip": [
#                     0,
#                     1,
#                     2,
#                     3,
#                     4
#                 ]
#             }
#         },
#         {
#             "type": "scatter",
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 2.5,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "x": "Country",
#                 "y": "Income",
#                 "tooltip": [
#                     0,
#                     1,
#                     2,
#                     3,
#                     4
#                 ]
#             }
#         },
#         {
#             "type": "scatter",
#             "xAxisIndex": 2,
#             "yAxisIndex": 2,
#             "symbolSize": 2.5,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "x": "Income",
#                 "y": "Population",
#                 "tooltip": [
#                     0,
#                     1,
#                     2,
#                     3,
#                     4
#                 ]
#             }
#         },
#         {
#             "type": "scatter",
#             "xAxisIndex": 3,
#             "yAxisIndex": 3,
#             "symbolSize": 2.5,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "x": "Life Expectancy",
#                 "y": "Population",
#                 "tooltip": [
#                     0,
#                     1,
#                     2,
#                     3,
#                     4
#                 ]
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "value",
#             "name": "Income",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 50,
#                 "margin": 8,
#                 "interval": 0
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "category",
#             "name": "Country",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 1,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 50,
#                 "margin": 8,
#                 "interval": 0
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "value",
#             "name": "Income",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 2,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 50,
#                 "margin": 8,
#                 "interval": 0
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "value",
#             "name": "Life Expectancy",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 3,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 50,
#                 "margin": 8,
#                 "interval": 0
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
