# %% [markdown]
# # Geo_Geo_chart_countries_js
# - 【Python数据可视化地理图AI教程】指定国家名称的行政区划地图
# - 输入国家名称显示该国行政区划地理图

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.datasets import register_url
import ssl

try:
    register_url("https://echarts-maps.github.io/echarts-countries-js/")
except Exception:
    ssl._create_default_https_context = ssl._create_unverified_context
    register_url("https://echarts-maps.github.io/echarts-countries-js/")

geo = (
    Geo()
    .add_schema(maptype="china")
    .set_global_opts(title_opts=opts.TitleOpts(title="china"))
#     .render("geo_chart_countries_js.html")
)
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="35ad82f889574ff1be6b78152e345411" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_35ad82f889574ff1be6b78152e345411 = echarts.init(
#                     document.getElementById('35ad82f889574ff1be6b78152e345411'), 'white', {renderer: 'canvas'});
#                 var option_35ad82f889574ff1be6b78152e345411 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# # Geo_Geo_lines_background
# - 【Python数据可视化地理图AI教程】可以设置颜色的地图上显示路线轨迹图
# - 指定2个地区显示一定线路轨迹图，并自定义地图颜色

# %%
list_data =[("广州", 55), ("北京", 66), ("杭州", 77), ("重庆", 88)]
list_line = [("广州", "上海"), ("广州", "北京"), ("广州", "杭州"), ("广州", "重庆")]

from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType

geo = (
    Geo()
    .add_schema(
        maptype="china",
        itemstyle_opts=opts.ItemStyleOpts(color="#323c48", border_color="#111"),
    )
    .add(
        "",
        list_data,
        type_=ChartType.EFFECT_SCATTER,
        color="white",
    )
    .add(
        "China Map",
        list_line,
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=10, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-Lines-background"))
#     .render("geo_lines_background.html")
)
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="702b923515c94e3893b3234e32b0b275" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_702b923515c94e3893b3234e32b0b275 = echarts.init(
#                     document.getElementById('702b923515c94e3893b3234e32b0b275'), 'white', {renderer: 'canvas'});
#                 var option_702b923515c94e3893b3234e32b0b275 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "white",
#         "#c23531",
#         "#2f4554",
# ...

# %% [markdown]
# # Geo_Geo_visualmap_piecewise
# - 【Python数据可视化地理图AI教程】地图上分段显示展示数据
# - 在地图上显示分段显示展示数据图

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

geo = (
    Geo()
    .add_schema(maptype="china")
    .add("China Map", [list(z) for z in zip(Faker.provinces, Faker.values())])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(is_piecewise=True),
        title_opts=opts.TitleOpts(title="Geo-VisualMap_piecewise"),
    )
#     .render("geo_visualmap_piecewise.html")
)
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="349b2cb9ecbb4249a2c9d06ea1e571b0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_349b2cb9ecbb4249a2c9d06ea1e571b0 = echarts.init(
#                     document.getElementById('349b2cb9ecbb4249a2c9d06ea1e571b0'), 'white', {renderer: 'canvas'});
#                 var option_349b2cb9ecbb4249a2c9d06ea1e571b0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# # Geo_Geo_lines
# - 【Python数据可视化地理图AI教程】地图上显示路线轨迹图
# - 指定2个地区显示一定线路轨迹图

# %%
list_data =[("广州", 55), ("北京", 66), ("杭州", 77), ("重庆", 88)]
list_line = [("广州", "上海"), ("广州", "北京"), ("广州", "杭州"), ("广州", "重庆")]

from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType

geo = (
    Geo()
    .add_schema(
        maptype="china",
    )
    .add(
        "",
        list_data,
        type_=ChartType.EFFECT_SCATTER,
        color="white",
    )
    .add(
        "China Map",
        list_line,
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=10, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-Lines-background"))
#     .render("geo_lines_background.html")
)
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="526ea146dd5f4926b0dcd3cecffe5fd8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_526ea146dd5f4926b0dcd3cecffe5fd8 = echarts.init(
#                     document.getElementById('526ea146dd5f4926b0dcd3cecffe5fd8'), 'white', {renderer: 'canvas'});
#                 var option_526ea146dd5f4926b0dcd3cecffe5fd8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "white",
#         "#c23531",
#         "#2f4554",
# ...

# %% [markdown]
# # Geo_Geo_Province
# - 【Python数据可视化地理图AI教程】指定省市地理图
# - 按照国家的省市进行地图绘制的地图

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker
from pyecharts.globals import ChartType

geo = (
    Geo().add_schema(maptype="广东").add(
    "Guangdong Map",
    [list(z) for z in zip(Faker.guangdong_city, Faker.values())],
    type_=ChartType.HEATMAP,
).set_series_opts(label_opts=opts.LabelOpts(is_show=False)).set_global_opts(
    visualmap_opts=opts.VisualMapOpts(),
    title_opts=opts.TitleOpts(
        title="Geo-Guangdong"))
#     .render("geo_province.html")
      )
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="2b1b20e56ebc43afbaea127eb9d2bdc2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_2b1b20e56ebc43afbaea127eb9d2bdc2 = echarts.init(
#                     document.getElementById('2b1b20e56ebc43afbaea127eb9d2bdc2'), 'white', {renderer: 'canvas'});
#                 var option_2b1b20e56ebc43afbaea127eb9d2bdc2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# # Geo_Geo_heatmap
# - 【Python数据可视化地理图AI教程】地图显示数据使用热力图方式显示
# - 地图显示数据使用热力图方式显示

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker
from pyecharts.globals import ChartType

geo = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "China Map",
        [list(z) for z in zip(Faker.provinces, Faker.values())],
        type_=ChartType.HEATMAP,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="Geo-HeatMap"),
    )
#     .render("geo_heatmap.html")
)
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="32607d7774d84d1f87c913fc4da7702d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_32607d7774d84d1f87c913fc4da7702d = echarts.init(
#                     document.getElementById('32607d7774d84d1f87c913fc4da7702d'), 'white', {renderer: 'canvas'});
#                 var option_32607d7774d84d1f87c913fc4da7702d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# # Geo_Geo_effectscatter
# - 【Python数据可视化地理图AI教程】地图显示数据使用涟漪图方式显示
# - 地图显示数据使用涟漪图方式显示

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker
from pyecharts.globals import ChartType

geo = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "China Map",
        [list(z) for z in zip(Faker.provinces, Faker.values())],
        type_=ChartType.EFFECT_SCATTER,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-EffectScatter"))
#     .render("geo_effectscatter.html")
)
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="ffde58f0fcf84a9694087c5a06a50348" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_ffde58f0fcf84a9694087c5a06a50348 = echarts.init(
#                     document.getElementById('ffde58f0fcf84a9694087c5a06a50348'), 'white', {renderer: 'canvas'});
#                 var option_ffde58f0fcf84a9694087c5a06a50348 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# # Geo_Geo_base
# - 【Python数据可视化地理图AI教程】基础地理图
# - 基础地理图

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

geo = (
    Geo()
    .add_schema(maptype="china")
    .add("China Map", [list(z) for z in zip(Faker.provinces, Faker.values())])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-Base")
    )
#     .render("geo_base.html")
)
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="8fee5ecfe6c84ee18f75615da7709d81" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_8fee5ecfe6c84ee18f75615da7709d81 = echarts.init(
#                     document.getElementById('8fee5ecfe6c84ee18f75615da7709d81'), 'white', {renderer: 'canvas'});
#                 var option_8fee5ecfe6c84ee18f75615da7709d81 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# # Geo_Geo_echart_china_js
# - 【Python数据可视化地理图AI教程】中国行政区划地图
# - 指定名称的中国行政区划地图

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.datasets import register_url

try:
    register_url("https://echarts-maps.github.io/echarts-china-counties-js/")
except Exception:
    import ssl

    ssl._create_default_https_context = ssl._create_unverified_context
    register_url("https://echarts-maps.github.io/echarts-china-counties-js/")

geo = (
    Geo()
    .add_schema(maptype="海淀区")
    .set_global_opts(title_opts=opts.TitleOpts(title="Hai Dian"))
#     .render("geo_echart_china_js.html")
)
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '海淀区':'https://echarts-maps.github.io/echarts-china-counties-js//echarts-china-counties-js/9af181f7c9d8308770d3a4a298ead8c6'
#         }
#     });
# </script>
#
#         <div id="c206ee8090fc4ad2b3b1839e667ebe51" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '海淀区'], function(echarts) {
#                 var chart_c206ee8090fc4ad2b3b1839e667ebe51 = echarts.init(
#                     document.getElementById('c206ee8090fc4ad2b3b1839e667ebe51'), 'white', {renderer: 'canvas'});
#                 var option_c206ee8090fc4ad2b3b1839e667ebe51 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
# ...
