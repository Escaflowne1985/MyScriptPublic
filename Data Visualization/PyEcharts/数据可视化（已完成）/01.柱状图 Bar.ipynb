# %% [markdown]
# https://gallery.pyecharts.org/#/Image/README

# %% [markdown]
# # Bar_Stack_bar_percent
# - 【Python数据可视化柱状图AI教程】类别聚合百分比堆积柱状图
# - 可以显示按类别数量百分比堆叠的可视化柱状图
# - https://www.zhihu.com/zvideo/1345116136409567232

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType

list2 = [
    {"value": 12, "percent": 12 / (12 + 3)},
    {"value": 23, "percent": 23 / (23 + 21)},
    {"value": 33, "percent": 33 / (33 + 5)},
    {"value": 3, "percent": 3 / (3 + 52)},
    {"value": 33, "percent": 33 / (33 + 43)},
]

list3 = [
    {"value": 3, "percent": 3 / (12 + 3)},
    {"value": 21, "percent": 21 / (23 + 21)},
    {"value": 5, "percent": 5 / (33 + 5)},
    {"value": 52, "percent": 52 / (3 + 52)},
    {"value": 43, "percent": 43 / (33 + 43)},
]

c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis([1, 2, 3, 4, 5])
    .add_yaxis("Lab A", list2, stack="stack1", category_gap="50%")
    .add_yaxis("Lab B", list3, stack="stack1", category_gap="50%")
    .set_series_opts(
        label_opts=opts.LabelOpts(
            position="right",
            formatter=JsCode(
                "function(x){return Number(x.data.percent * 100).toFixed() + '%';}"
            ),
        )
    )
#     .render("stack_bar_percent.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="aad5c50882ec44cbb04c341eba2b3aac" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_aad5c50882ec44cbb04c341eba2b3aac = echarts.init(
#                     document.getElementById('aad5c50882ec44cbb04c341eba2b3aac'), 'light', {renderer: 'canvas'});
#                 var option_aad5c50882ec44cbb04c341eba2b3aac = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "Lab A",
#             "data": [
#                 {
# ...

# %% [markdown]
# # Bar_rotate_xaxis_label
# - 【Python数据可视化柱状图AI教程】X轴标签可以旋转的柱状图
# - X轴标签可以旋转的可视化柱状图，解决标签名字过长的问题
# - https://www.zhihu.com/zvideo/1345117029515444225

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

c = (
    Bar()
    .add_xaxis(
        [
            "Long X-axis label 1",
            "Long X-axis label 2",
            "Long X-axis label 3",
            "Long X-axis label 4",
            "Long X-axis label 5",
            "Long X-axis label 6",
        ]
    )
    .add_yaxis("Lab A", [10, 20, 30, 40, 50, 40])
    .add_yaxis("Lab B", [20, 10, 40, 30, 40, 50])
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="Bar-Rotate X axis label", subtitle="Solve the problem that the label name is too long"),
    )
#     .render("bar_rotate_xaxis_label.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0d2fad5fe49b4b5fae676e29c2c5e545" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0d2fad5fe49b4b5fae676e29c2c5e545 = echarts.init(
#                     document.getElementById('0d2fad5fe49b4b5fae676e29c2c5e545'), 'white', {renderer: 'canvas'});
#                 var option_0d2fad5fe49b4b5fae676e29c2c5e545 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_stack0
# - 【Python数据可视化柱状图AI教程】类别聚合数量堆积柱状图
# - 按类别数量数据堆叠的可视化柱状图
# - https://www.zhihu.com/zvideo/1345117029515444225

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values(), stack="stack1")
    .add_yaxis("Lab B", Faker.values(), stack="stack1")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar-Stack data (all)"))
#     .render("bar_stack0.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e78b0dc2da2c416a823f1558b9b4a2d9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e78b0dc2da2c416a823f1558b9b4a2d9 = echarts.init(
#                     document.getElementById('e78b0dc2da2c416a823f1558b9b4a2d9'), 'white', {renderer: 'canvas'});
#                 var option_e78b0dc2da2c416a823f1558b9b4a2d9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_
        4486.74,
        2025.44,
        2493.04,
        6821.11,
        9730.91,
        7613.46,
        2789.78,
        3770,
        1918.95,
        8620.24,
        4511.97,
        3812.34,
        3835.4,
        14076.83,
        2156.76,
        528.84,
        1825.21,
        3881.6,
        1312.94,
        1896.78,
        188.06,
        2178.2,
        1037.11,
        294.91,
        366.18,
        1246.89,
    ],
    2006: [
        5837.55,
        1902.31,
        3895.36,
        1846.18,
        1934.35,
        3798.26,
        1687.07,
        2096.35,
        5508.48,
        7914.11,
        6281.86,
        2390.29,
        3022.83,
        1614.65,
        7187.26,
        3721.44,
        3111.98,
        3229.42,
        11585.82,
        1835.12,
        433.57,
        1649.2,
        3319.62,
        989.38,
        1557.91,
        159.76,
        1806.36,
        900.16,
        249.04,
        294.78,
        1058.16,
    ],
    2005: [
        4854.33,
        1658.19,
        3340.54,
        1611.07,
        1542.26,
        3295.45,
        1413.83,
        1857.42,
        4776.2,
        6612.22,
        5360.1,
        2137.77,
        2551.41,
        1411.92,
        5924.74,
        3181.27,
        2655.94,
        2882.88,
        9772.5,
        1560.92,
        377.17,
        1440.32,
        2836.73,
        815.32,
        1374.62,
        137.24,
        1546.59,
        787.36,
        213.37,
        259.49,
        929.41,
    ],
    2004: [
        4092.27,
        1319.76,
        2805.47,
        1375.67,
        1270,
        2811.95,
        1223.64,
        1657.77,
        4097.26,
        5198.03,
        4584.22,
        1963.9,
        2206.02,
        1225.8,
        4764.7,
        2722.4,
        2292.55,
        2428.95,
        8335.3,
        1361.92,
        335.3,
        1229.62,
        2510.3,
        661.8,
        1192.53,
        123.3,
        1234.6,
        688.41,
        193.7,
        227.73,
        833.36,
    ],
    2003: [
        3435.95,
        1150.81,
        2439.68,
        1176.65,
        1000.79,
        2487.85,
        1075.48,
        1467.9,
        3404.19,
        4493.31,
        3890.79,
        1638.42,
        1949.91,
        1043.08,
        4112.43,
        2358.86,
        2003.08,
        1995.78,
        7178.94,
        1178.25,
        293.85,
        1081.35,
        2189.68,
        558.28,
        1013.76,
        96.76,
        1063.89,
        589.91,
        169.81,
        195.46,
        753.91,
    ],
    2002: [
        2982.57,
        997.47,
        2149.75,
        992.69,
        811.47,
        2258.17,
        958.88,
        1319.4,
        3038.9,
        3891.92,
        3227.99,
        1399.02,
        1765.8,
        972.73,
        3700.52,
        1978.37,
        1795.93,
        1780.79,
        6343.94,
        1074.85,
        270.96,
        956.12,
        1943.68,
        480.37,
        914.5,
        89.56,
        963.62,
        514.83,
        148.83,
        171.14,
        704.5,
    ],
}

import pyecharts.options as opts
from pyecharts.charts import Timeline, Bar, Pie


def format_data(data: dict) -> dict:
    for year in range(2002, 2012):
        max_data, sum_data = 0, 0
        temp = data[year]
        max_data = max(temp)
        for i in range(len(temp)):
            sum_data += temp[i]
            data[year][i] = {"name": name_list[i], "value": temp[i]}
        data[str(year) + "max"] = int(max_data / 100) * 100
        data[str(year) + "sum"] = sum_data
    return data



total_data["dataGDP"] = format_data(data=data_gdp)
total_data["dataPI"] = format_data(data=data_pi)
total_data["dataSI"] = format_data(data=data_si)
total_data["dataTI"] = format_data(data=data_ti)
total_data["dataEstate"] = format_data(data=data_estate)
total_data["dataFinancial"] = format_data(data=data_financial)


#####################################################################################
# 2002 - 2011 data
def get_year_overlap_chart(year: int) -> Bar:
    bar = (
        Bar()
        .add_xaxis(xaxis_data=name_list)
        .add_yaxis(
            series_name="GDP",
            yaxis_data=total_data["dataGDP"][year],
            is_selected=False,
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add_yaxis(
            series_name="Financial",
            yaxis_data=total_data["dataFinancial"][year],
            is_selected=False,
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add_yaxis(
            series_name="Estate",
            yaxis_data=total_data["dataEstate"][year],
            is_selected=False,
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add_yaxis(
            series_name="PI",
            yaxis_data=total_data["dataPI"][year],
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add_yaxis(
            series_name="SI",
            yaxis_data=total_data["dataSI"][year],
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add_yaxis(
            series_name="TI",
            yaxis_data=total_data["dataTI"][year],
            label_opts=opts.LabelOpts(is_show=False),
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(
                title="{}National macroeconomic indicators".format(year), subtitle="Data comes from the National Bureau of Statistics"
            ),
            tooltip_opts=opts.TooltipOpts(
                is_show=True, trigger="axis", axis_pointer_type="shadow"
            ),
        )
    )
    pie = (
        Pie()
        .add(
            series_name="GDP Percentage",
            data_pair=[
                ["PI", total_data["dataPI"]["{}sum".format(year)]],
                ["SI", total_data["dataSI"]["{}sum".format(year)]],
                ["TI", total_data["dataTI"]["{}sum".format(year)]],
            ],
            center=["75%", "35%"],
            radius="28%",
        )
        .set_series_opts(tooltip_opts=opts.TooltipOpts(is_show=True, trigger="item"))
    )
    return bar.overlap(pie)


# timeline
timeline = Timeline(init_opts=opts.InitOpts(width="900px", height="600px"))

for y in range(2002, 2012):
    timeline.add(get_year_overlap_chart(year=y), time_point=str(y))


timeline.add_schema(is_auto_play=True, play_interval=1000)
# timeline.render("finance_indices_2002.html")
timeline.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0aabec5e209147c2bc521042e4e7fbfa" style="width:900px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0aabec5e209147c2bc521042e4e7fbfa = echarts.init(
#                     document.getElementById('0aabec5e209147c2bc521042e4e7fbfa'), 'white', {renderer: 'canvas'});
#                 var option_0aabec5e209147c2bc521042e4e7fbfa = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "GDP",
#                 "data": [
#                     {
#                         "name": "Beijing",
#                         "value": 16251.93
#                     },
#                     {
#                         "name": "Tianjin",
#                         "value": 11307.28
# ...

# %% [markdown]
# # Bar_Bar_base_dict_config
# - 【Python数据可视化柱状图AI教程】数据为字典格式柱状图
# - 可以通过dict进行配置的可视化柱状图
# - https://www.zhihu.com/zvideo/1345457515467788288

# %%
from pyecharts.charts import Bar
from pyecharts.faker import Faker
from pyecharts.globals import ThemeType

c = (
    Bar({"theme": ThemeType.MACARONS})
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(
        title_opts={"text": "Bar-configure via dict", "subtext": "Bar-configure via dict also"}
    )
#     .render("bar_base_dict_config.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons'
#         }
#     });
# </script>
#
#         <div id="ce415d33187643dbaf14db1815fa6b0e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'macarons'], function(echarts) {
#                 var chart_ce415d33187643dbaf14db1815fa6b0e = echarts.init(
#                     document.getElementById('ce415d33187643dbaf14db1815fa6b0e'), 'macarons', {renderer: 'canvas'});
#                 var option_ce415d33187643dbaf14db1815fa6b0e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
# ...

# %% [markdown]
# # Bar_Bar_with_brush
# - 【Python数据可视化柱状图AI教程】携带画笔柱状图
# - 可以使用画笔选择显示数据的可视化柱状图
# - https://www.zhihu.com/zvideo/1345457842795573248

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar_with_brush", subtitle="Bar_with_brush"),
        brush_opts=opts.BrushOpts(),
    )
#     .render("bar_with_brush.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cd2ca79d48e040e59a274cf6ce038317" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cd2ca79d48e040e59a274cf6ce038317 = echarts.init(
#                     document.getElementById('cd2ca79d48e040e59a274cf6ce038317'), 'white', {renderer: 'canvas'});
#                 var option_cd2ca79d48e040e59a274cf6ce038317 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_datazoom_slider
# - 【Python数据可视化柱状图AI教程】数据缩放柱状图
# - 可以拖动X轴数据滑块进行数据缩放选择的可视化柱状图
# - https://www.zhihu.com/zvideo/1345457004803022848

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.days_attrs)
    .add_yaxis("Lab A", Faker.days_values)
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar_datazoom_slider"),
        datazoom_opts=opts.DataZoomOpts(),
    )
#     .render("bar_datazoom_slider.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dbe29c91f2624907b3ff03cfb2c8b188" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dbe29c91f2624907b3ff03cfb2c8b188 = echarts.init(
#                     document.getElementById('dbe29c91f2624907b3ff03cfb2c8b188'), 'white', {renderer: 'canvas'});
#                 var option_dbe29c91f2624907b3ff03cfb2c8b188 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_toolbox
# - 【Python数据可视化柱状图AI教程】携带工具箱柱状图
# - 可以使用工具箱操作的可视化柱状图
# - https://www.zhihu.com/zvideo/1345457691926540289

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-ToolBox"),
        toolbox_opts=opts.ToolboxOpts(),
        legend_opts=opts.LegendOpts(is_show=False),
    )
#     .render("bar_toolbox.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="aae90f5da3624711be06b4d50fa7a690" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_aae90f5da3624711be06b4d50fa7a690 = echarts.init(
#                     document.getElementById('aae90f5da3624711be06b4d50fa7a690'), 'white', {renderer: 'canvas'});
#                 var option_aae90f5da3624711be06b4d50fa7a690 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_waterfall_plot
# - 【Python数据可视化柱状图AI教程】瀑布式柱状图
# - 瀑布式可视化柱状图
# - https://www.zhihu.com/zvideo/1346898972318027776

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

x_data = [f"Feb. {str(i)} " for i in range(1, 12)]
y_total = [0, 900, 1245, 1530, 1376, 1376, 1511, 1689, 1856, 1495, 1292]
y_in = [900, 345, 393, "-", "-", 135, 178, 286, "-", "-", "-"]
y_out = ["-", "-", "-", 108, 154, "-", "-", "-", 119, 361, 203]


bar = (
    Bar()
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="",
        yaxis_data=y_total,
        stack="Total",
        itemstyle_opts=opts.ItemStyleOpts(color="rgba(0,0,0,0)"),
    )
    .add_yaxis(series_name="income", yaxis_data=y_in, stack="Total")
    .add_yaxis(series_name="expenses", yaxis_data=y_out, stack="Total")
    .set_global_opts(yaxis_opts=opts.AxisOpts(type_="value"))
#     .render("bar_waterfall_plot.html")
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="61bad61086ff4ef1af2c3ee0b42573b9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_61bad61086ff4ef1af2c3ee0b42573b9 = echarts.init(
#                     document.getElementById('61bad61086ff4ef1af2c3ee0b42573b9'), 'white', {renderer: 'canvas'});
#                 var option_61bad61086ff4ef1af2c3ee0b42573b9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Mixed_bar_and_line
# - 【Python数据可视化柱状图AI教程】柱状、线性组合图
# - 柱状、线性组合可视化图表
# - https://www.zhihu.com/zvideo/1346899192506490880

# %%
import pyecharts.options as opts
from pyecharts.charts import Bar, Line

x_data = ["Jan.", "Feb.", "Mar.", "Apr.", "May.", "Jun.", "Jul.", "Aug.", "September.", "Oct.", "Nov.", "Dec."]
y_data_Evaporation = [2.0,4.9,7.0,23.2,25.6,76.7,135.6,162.2,32.6,20.0,6.4,3.3,]
y_data_Precipitation = [2.6,5.9,9.0,26.4,28.7,70.7,175.6,182.2,48.7,18.8,6.0,2.3,]
y_data_Temperature = [2.0, 2.2, 3.3, 4.5, 6.3, 10.2, 20.3, 23.4, 23.0, 16.5, 12.0, 6.2]

bar = (
    Bar(init_opts=opts.InitOpts(width="1000px", height="600px"))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="Evaporation",
        yaxis_data=y_data_Evaporation,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add_yaxis(
        series_name="Precipitation",
        yaxis_data=y_data_Precipitation,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="temperature",
            type_="value",
            min_=0,
            max_=25,
            interval=5,
            axislabel_opts=opts.LabelOpts(formatter="{value} °C"),
        )
    )
    .set_global_opts(
        tooltip_opts=opts.TooltipOpts(
            is_show=True, trigger="axis", axis_pointer_type="cross"
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            axispointer_opts=opts.AxisPointerOpts(is_show=True, type_="shadow"),
        ),
        yaxis_opts=opts.AxisOpts(
            name="Water",
            type_="value",
            min_=0,
            max_=250,
            interval=50,
            axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    )
)

line = (
    Line()
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="average temperature",
        yaxis_index=1,
        y_axis=y_data_Temperature,
        label_opts=opts.LabelOpts(is_show=False),
    )
)
# bar.overlap(line).render("mixed_bar_and_line.html")
bar.overlap(line).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ea58e71dac1b4d76b55f3be4f63f6276" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ea58e71dac1b4d76b55f3be4f63f6276 = echarts.init(
#                     document.getElementById('ea58e71dac1b4d76b55f3be4f63f6276'), 'white', {renderer: 'canvas'});
#                 var option_ea58e71dac1b4d76b55f3be4f63f6276 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_grahic_component
# - 【Python数据可视化柱状图AI教程】携带组件柱状图
# - 携带图形组件的可视化柱状图
# - https://www.zhihu.com/zvideo/1346899883966844929

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-Graphic Component"),
        graphic_opts=[
            opts.GraphicGroup(
                graphic_item=opts.GraphicItem(
                    rotation=JsCode("Math.PI / 4"),
                    bounding="raw",
                    right=110,
                    bottom=110,
                    z=100,
                ),
                children=[
                    opts.GraphicRect(
                        graphic_item=opts.GraphicItem(
                            left="center", top="center", z=100
                        ),
                        graphic_shape_opts=opts.GraphicShapeOpts(width=400, height=50),
                        graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                            fill="rgba(0,0,0,0.3)"
                        ),
                    ),
                    opts.GraphicText(
                        graphic_item=opts.GraphicItem(
                            left="center", top="center", z=100
                        ),
                        graphic_textstyle_opts=opts.GraphicTextStyleOpts(
                            text="pyecharts bar chart",
                            font="bold 26px Microsoft YaHei",
                            graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                                fill="#fff"
                            ),
                        ),
                    ),
                ],
            )
        ],
    )
#     .render("bar_graphic_component.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8a04cf9d146044b8b7f80fc83d0091ec" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8a04cf9d146044b8b7f80fc83d0091ec = echarts.init(
#                     document.getElementById('8a04cf9d146044b8b7f80fc83d0091ec'), 'white', {renderer: 'canvas'});
#                 var option_8a04cf9d146044b8b7f80fc83d0091ec = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_stack1
# - 【Python数据可视化柱状图AI教程】部分数据堆叠柱状图
# - 可控制的部分数据堆叠的可视化柱状图
# - https://www.zhihu.com/zvideo/1346900126598832128

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values(), stack="stack1")
    .add_yaxis("Lab B", Faker.values(), stack="stack1")
    .add_yaxis("Lab C", Faker.values())
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar-stack data (partial)"))
#     .render("bar_stack1.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="967e4fc1f4964f33ba3615c68012897c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_967e4fc1f4964f33ba3615c68012897c = echarts.init(
#                     document.getElementById('967e4fc1f4964f33ba3615c68012897c'), 'white', {renderer: 'canvas'});
#                 var option_967e4fc1f4964f33ba3615c68012897c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_xyaxis_name
# - 【Python数据可视化柱状图AI教程】自定义的X、Y轴名称柱状图
# - X、Y轴可以自定义名称的可视化柱状图
# - https://www.zhihu.com/zvideo/1346900443956645888

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-XY axis name"),
        yaxis_opts=opts.AxisOpts(name="here Y axis name"),
        xaxis_opts=opts.AxisOpts(name="here X axis name"),
    )
#     .render("bar_xyaxis_name.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="21777a48d1e64325a31e7d77656f87c8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_21777a48d1e64325a31e7d77656f87c8 = echarts.init(
#                     document.getElementById('21777a48d1e64325a31e7d77656f87c8'), 'white', {renderer: 'canvas'});
#                 var option_21777a48d1e64325a31e7d77656f87c8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_base_with_custom_background_image
# - 【Python数据可视化柱状图AI教程】自定义背景的柱状图
# - 可以自定义背景图片的可视化柱状图
# - https://www.zhihu.com/zvideo/1346900932765118466

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.faker import Faker

c = (
    Bar(
        init_opts=opts.InitOpts(
            bg_color={"type": "pattern", "image": JsCode("img"), "repeat": "no-repeat"}
        )
    )
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="with_custom_background_image",
            subtitle="subtitle",
            title_textstyle_opts=opts.TextStyleOpts(color="white"),
        )
    )
)
c.add_js_funcs(
    """
    var img = new Image(); img.src = 'http://qqpublic.qpic.cn/qq_public/0/0-3104979443-4A92570F168C9D96D5FC83BE9AA579D3/0?fmt=jpg&size=86&h=690&w=690&ppv=1/0';
    """
)
# c.render("bar_base_with_custom_background_image.html")
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8bb4d5be39b2409ab119cb0e2ca6e40d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8bb4d5be39b2409ab119cb0e2ca6e40d = echarts.init(
#                     document.getElementById('8bb4d5be39b2409ab119cb0e2ca6e40d'), 'white', {renderer: 'canvas'});
#
#     var img = new Image(); img.src = 'http://qqpublic.qpic.cn/qq_public/0/0-3104979443-4A92570F168C9D96D5FC83BE9AA579D3/0?fmt=jpg&size=86&h=690&w=690&ppv=1/0';
#
#                 var option_8bb4d5be39b2409ab119cb0e2ca6e40d = {
#     "backgroundColor": {
#         "type": "pattern",
#         "image": img,
#         "repeat": "no-repeat"
#     },
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
# ...

# %% [markdown]
# # Bar_Bar_chart_display_delay
# - 【Python数据可视化柱状图AI教程】动态柱状图
# - 具有动画延迟效果的可视化柱状图
# - https://www.zhihu.com/zvideo/1346901135110967297

# %%
import pyecharts.options as opts
from pyecharts.charts import Bar
import random

n = 30
category = ["type{}".format(i) for i in range(0, n)]
red_bar = [round(random.uniform(-5, 5) +random.uniform(-0.005,0.005), 2) for i in range(n)]
blue_bar = [round(random.uniform(-5, 5) +random.uniform(-0.005,0.005), 2) for i in range(n)]


c = (
    Bar(init_opts=opts.InitOpts(width="1000px", height="600px"))
    .add_xaxis(xaxis_data=category)
    .add_yaxis(
        series_name="bar", yaxis_data=red_bar, label_opts=opts.LabelOpts(is_show=False)
    )
    .add_yaxis(
        series_name="bar2",
        yaxis_data=blue_bar,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar_Bar_chart_display_delay"),
        xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=False)),
        yaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    )
#     .render("bar_chart_display_delay.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="515ecc14e4f940c98759c699d9a1ad69" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_515ecc14e4f940c98759c699d9a1ad69 = echarts.init(
#                     document.getElementById('515ecc14e4f940c98759c699d9a1ad69'), 'white', {renderer: 'canvas'});
#                 var option_515ecc14e4f940c98759c699d9a1ad69 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_datazoom_slider_vertical
# - 【Python数据可视化柱状图AI教程】Y轴动态选取柱状图
# - 可以拖动Y轴数据滑块进行数据缩放选择的可视化柱状图
# - https://www.zhihu.com/zvideo/1346901578465636352

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.days_attrs)
    .add_yaxis("Lab A", Faker.days_values, color=Faker.rand_color())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar_datazoom_slider"),
        datazoom_opts=opts.DataZoomOpts(orient="vertical"),
    )
#     .render("bar_datazoom_slider_vertical.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e61184425ad540e68c9c11bca5e9d357" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e61184425ad540e68c9c11bca5e9d357 = echarts.init(
#                     document.getElementById('e61184425ad540e68c9c11bca5e9d357'), 'white', {renderer: 'canvas'});
#                 var option_e61184425ad540e68c9c11bca5e9d357 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#6d8346",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

# %% [markdown]
# # Bar_Bar_histogram_color
# - 【Python数据可视化柱状图AI教程】色彩区分的直方图
# - 可以根据颜色区分数据比例的可视化直方图
# - https://www.zhihu.com/zvideo/1346901854236958720

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


x = Faker.dogs + Faker.animal
xlen = len(x)
y = []
for idx, item in enumerate(x):
    if idx <= xlen / 2:
        y.append(
            opts.BarItem(
                name=item,
                value=(idx + 1) * 10,
                itemstyle_opts=opts.ItemStyleOpts(color="#749f83"),
            )
        )
    else:
        y.append(
            opts.BarItem(
                name=item,
                value=(xlen + 1 - idx) * 10,
                itemstyle_opts=opts.ItemStyleOpts(color="#d48265"),
            )
        )

c = (
    Bar()
    .add_xaxis(x)
    .add_yaxis("series0", y, category_gap=0, color=Faker.rand_color())
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_histogram_color"))
#     .render("bar_histogram_color.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b14cd7a7637d4ca994b342d68112acd8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b14cd7a7637d4ca994b342d68112acd8 = echarts.init(
#                     document.getElementById('b14cd7a7637d4ca994b342d68112acd8'), 'white', {renderer: 'canvas'});
#                 var option_b14cd7a7637d4ca994b342d68112acd8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#6d8346",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

# %% [markdown]
# # Bar_Bar_yaxis_formatter
# - 【Python数据可视化柱状图AI教程】自定义Y轴刻度柱状图
# - 可以自定义格式化Y轴刻度的可视化柱状图
# - https://www.zhihu.com/zvideo/1346902370312466432

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar_Bar_yaxis_formatter"),
        yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(formatter="{value} /day")),
    )
#     .render("bar_yaxis_formatter.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="442fe96f1c2544b1a32624561152cc9e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_442fe96f1c2544b1a32624561152cc9e = echarts.init(
#                     document.getElementById('442fe96f1c2544b1a32624561152cc9e'), 'white', {renderer: 'canvas'});
#                 var option_442fe96f1c2544b1a32624561152cc9e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_markpoint_type
# - 【Python数据可视化柱状图AI教程】自定义标记点柱状图
# - 可以带有自定义标记点的可视化柱状图
# - https://www.zhihu.com/zvideo/1346902569629954048

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_markpoint_type"))
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
        markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="max", name="max"),
                opts.MarkPointItem(type_="min", name="min"),
                opts.MarkPointItem(type_="average", name="avg"),
            ]
        ),
    )
#     .render("bar_markpoint_type.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1d8876976d874f4db4489198a29ed8aa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1d8876976d874f4db4489198a29ed8aa = echarts.init(
#                     document.getElementById('1d8876976d874f4db4489198a29ed8aa'), 'white', {renderer: 'canvas'});
#                 var option_1d8876976d874f4db4489198a29ed8aa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Multiple_y_axes
# - 【Python数据可视化柱状图AI教程】复合柱状、线性组合图
# - 可以复合显示Y轴刻度的可视化柱状、线性可视化图表
# - https://www.zhihu.com/zvideo/1346902736559030272

# %%
import pyecharts.options as opts
from pyecharts.charts import Bar, Line

colors = ["#5793f3", "#d14a61", "#675bba"]
x_data = ["Jan.", "Feb.", "Mar.", "Apr.", "May.", "Jun.", "Jul.", "Aug.", "September.", "Oct.", "Nov.", "Dec."]
legend_list = ["evaporation", "rainfall", "average_temperature"]
evaporation_capacity =[2.0,4.9,7.0,23.2,25.6,76.7,135.6,162.2,32.6,20.0,6.4,3.3,]
rainfall_capacity = [2.6,5.9,9.0,26.4,28.7,70.7,175.6,182.2,48.7,18.8,6.0,2.3,]
average_temperature = [2.0, 2.2, 3.3, 4.5, 6.3, 10.2, 20.3, 23.4, 23.0, 16.5, 12.0, 6.2]

bar = (
    Bar(init_opts=opts.InitOpts(width="900px", height="600px"))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="evaporation",
        yaxis_data=evaporation_capacity,
        yaxis_index=0,
        color=colors[1],
    )
    .add_yaxis(
        series_name="rainfall", yaxis_data=rainfall_capacity, yaxis_index=1, color=colors[0]
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="evaporation",
            type_="value",
            min_=0,
            max_=250,
            position="right",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color=colors[1])
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
        )
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            type_="value",
            name="temperature",
            min_=0,
            max_=25,
            position="left",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color=colors[2])
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} °C"),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=1)
            ),
        )
    )
    .set_global_opts(
        yaxis_opts=opts.AxisOpts(
            type_="value",
            name="rainfall",
            min_=0,
            max_=250,
            position="right",
            offset=80,
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color=colors[0])
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
        ),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
    )
)

line = (
    Line()
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="average_temperature", y_axis=average_temperature, yaxis_index=2, color=colors[2]
    )
)

# bar.overlap(line).render("multiple_y_axes.html")
bar.overlap(line).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0712c84d108f4e9ea9df0fa8a28a9c97" style="width:900px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0712c84d108f4e9ea9df0fa8a28a9c97 = echarts.init(
#                     document.getElementById('0712c84d108f4e9ea9df0fa8a28a9c97'), 'white', {renderer: 'canvas'});
#                 var option_0712c84d108f4e9ea9df0fa8a28a9c97 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#5793f3",
#         "#d14a61",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
# ...

# %% [markdown]
# # Bar_Bar_custom_bar_color
# - 【Python数据可视化柱状图AI教程】自定义数据颜色的柱状图
# - 可以自定义柱状图数据颜色的可视化柱状图
# - https://www.zhihu.com/zvideo/1347097254696730624

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.faker import Faker


color_function = """
        function (params) {
            if (params.value > 0 && params.value < 50) {
                return 'red';
            } else if (params.value > 50 && params.value < 100) {
                return 'blue';
            }
            return 'green';
        }
        """
c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis(
        "Lab A",
        Faker.values(),
        itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_function)),
    )
    .add_yaxis(
        "Lab B",
        Faker.values(),
        itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_function)),
    )
    .add_yaxis(
        "Lab C",
        Faker.values(),
        itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_function)),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_custom_bar_color"))
#     .render("bar_custom_bar_color.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1000fe5e6e7344fb88f01d940a72c319" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1000fe5e6e7344fb88f01d940a72c319 = echarts.init(
#                     document.getElementById('1000fe5e6e7344fb88f01d940a72c319'), 'white', {renderer: 'canvas'});
#                 var option_1000fe5e6e7344fb88f01d940a72c319 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_different_series_gap
# - 【Python数据可视化柱状图AI教程】类别数据设置间隔柱状图
# - 可以根据类别区分数据并设置间隔的可视化柱状图
# - https://www.zhihu.com/zvideo/1347097474306297856

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values(), gap="0%")
    .add_yaxis("Lab B", Faker.values(), gap="0%")
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_different_series_gap"))
#     .render("bar_different_series_gap.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f3eb2e16738f4248a687675e62f63197" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f3eb2e16738f4248a687675e62f63197 = echarts.init(
#                     document.getElementById('f3eb2e16738f4248a687675e62f63197'), 'white', {renderer: 'canvas'});
#                 var option_f3eb2e16738f4248a687675e62f63197 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_markline_type
# - 【Python数据可视化柱状图AI教程】指定类型数据标记线柱状图
# - 携带指定数据标记线的可视化柱状图
# - https://www.zhihu.com/zvideo/1347097672592015360

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_markline_type"))
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
        markline_opts=opts.MarkLineOpts(
            data=[
                opts.MarkLineItem(type_="min", name="min"),
                opts.MarkLineItem(type_="max", name="max"),
                opts.MarkLineItem(type_="average", name="avg"),
            ]
        ),
    )
#     .render("bar_markline_type.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="652044a4558440a0a53a63b51a7118ef" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_652044a4558440a0a53a63b51a7118ef = echarts.init(
#                     document.getElementById('652044a4558440a0a53a63b51a7118ef'), 'white', {renderer: 'canvas'});
#                 var option_652044a4558440a0a53a63b51a7118ef = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_border_radius
# - 【Python数据可视化柱状图AI教程】数据柱状颜色渐变柱状图
# - 数据颜色渐变的可视化柱状图
# - https://www.zhihu.com/zvideo/1347097840209133568

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values(), category_gap="60%")
    .set_series_opts(
        itemstyle_opts={
            "normal": {
                "color": JsCode(
                    """new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                offset: 0,
                color: 'rgba(0, 244, 255, 1)'
            }, {
                offset: 1,
                color: 'rgba(0, 77, 167, 1)'
            }], false)"""
                ),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": "rgb(0, 160, 221)",
            }
        }
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_border_radius"))
#     .render("bar_border_radius.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="89349816017147a6bbdeaecfb167e6ff" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_89349816017147a6bbdeaecfb167e6ff = echarts.init(
#                     document.getElementById('89349816017147a6bbdeaecfb167e6ff'), 'white', {renderer: 'canvas'});
#                 var option_89349816017147a6bbdeaecfb167e6ff = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_same_series_gap
# - 【Python数据可视化柱状图AI教程】类别数据间隔相同柱状图
# - 可以设置数据间具有相同间距的可视化柱状图
# - https://www.zhihu.com/zvideo/1347098159617900544

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values(), category_gap="80%")
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_same_series_gap"))
#     .render("bar_same_series_gap.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c5340b5fbf02469fb4606bcee933c9e5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c5340b5fbf02469fb4606bcee933c9e5 = echarts.init(
#                     document.getElementById('c5340b5fbf02469fb4606bcee933c9e5'), 'white', {renderer: 'canvas'});
#                 var option_c5340b5fbf02469fb4606bcee933c9e5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_datazoom_inside
# - 【Python数据可视化柱状图AI教程】图表内部滑块拖动缩放柱状图
# - 数据可视化图表中内部可以通过滑块进行数据缩放选择的可视化柱状图
# - https://www.zhihu.com/zvideo/1347098363763097600

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.days_attrs)
    .add_yaxis("Lab A", Faker.days_values, color=Faker.rand_color())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar_datazoom_inside"),
        datazoom_opts=opts.DataZoomOpts(type_="inside"),
    )
#     .render("bar_datazoom_inside.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1700304473d04308ad96c96ce12510cb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1700304473d04308ad96c96ce12510cb = echarts.init(
#                     document.getElementById('1700304473d04308ad96c96ce12510cb'), 'white', {renderer: 'canvas'});
#                 var option_1700304473d04308ad96c96ce12510cb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#2f4554",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

# %% [markdown]
# # Bar_Bar_is_selected
# - 【Python数据可视化柱状图AI教程】有选择显示的柱状图
# - 默认选择取消某列数据的可视化柱状图
# - https://www.zhihu.com/zvideo/1347098934117003265

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values(), is_selected=False)
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_is_selected"))
#     .render("bar_is_selected.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5f6937f2d4d9457395277417e1002fff" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5f6937f2d4d9457395277417e1002fff = echarts.init(
#                     document.getElementById('5f6937f2d4d9457395277417e1002fff'), 'white', {renderer: 'canvas'});
#                 var option_5f6937f2d4d9457395277417e1002fff = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_reversal_axis
# - 【Python数据可视化柱状图AI教程】横向显示数据的柱状图
# - X、Y轴逆转的横向可视化柱状图
# - https://www.zhihu.com/zvideo/1347099089146937344

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position="right"))
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_reversal_axis"))
#     .render("bar_reversal_axis.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4ea9f7b2510e48ad8412b404947ffffd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4ea9f7b2510e48ad8412b404947ffffd = echarts.init(
#                     document.getElementById('4ea9f7b2510e48ad8412b404947ffffd'), 'white', {renderer: 'canvas'});
#                 var option_4ea9f7b2510e48ad8412b404947ffffd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_markpoint_custom
# - 【Python数据可视化柱状图AI教程】自定义数据标记点柱状图
# - 自定义标记点的可视化柱状图
# - https://www.zhihu.com/zvideo/1347099293300469760

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

x, y = Faker.choose(), Faker.values()
c = (
    Bar()
    .add_xaxis(x)
    .add_yaxis(
        "Lab A",
        y,
        markpoint_opts=opts.MarkPointOpts(
            data=[opts.MarkPointItem(name="markpoint_custom", coord=[x[3], y[3]], value=y[2])]
        ),
    )
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_markpoint_custom"))
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
#     .render("bar_markpoint_custom.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b7f588d0237f4ef5a454a507cc6d5d3f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b7f588d0237f4ef5a454a507cc6d5d3f = echarts.init(
#                     document.getElementById('b7f588d0237f4ef5a454a507cc6d5d3f'), 'white', {renderer: 'canvas'});
#                 var option_b7f588d0237f4ef5a454a507cc6d5d3f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_base_with_animation
# - 【Python数据可视化柱状图AI教程】具有动画延迟效果的柱状图
# - 动画配置基础的可视化柱状图
# - https://www.zhihu.com/zvideo/1347105078893989888

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar(
        init_opts=opts.InitOpts(
            animation_opts=opts.AnimationOpts(
                animation_delay=2000, animation_easing="elasticOut"
            )
        )
    )
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_base_with_animation", subtitle="subtitle"))
#     .render("bar_base_with_animation.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3044d853e25d4573a487ec76d917a935" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3044d853e25d4573a487ec76d917a935 = echarts.init(
#                     document.getElementById('3044d853e25d4573a487ec76d917a935'), 'white', {renderer: 'canvas'});
#                 var option_3044d853e25d4573a487ec76d917a935 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "elasticOut",
#     "animationDelay": 2000,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_histogram
# - 【Python数据可视化柱状图AI教程】标准直方图
# - 标准可视化直方图
# - https://www.zhihu.com/zvideo/1347105278802915328

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values(), category_gap=0, color=Faker.rand_color())
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_histogram"))
#     .render("bar_histogram.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1e2da79275f045fea9d54c1bd0e34181" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1e2da79275f045fea9d54c1bd0e34181 = echarts.init(
#                     document.getElementById('1e2da79275f045fea9d54c1bd0e34181'), 'white', {renderer: 'canvas'});
#                 var option_1e2da79275f045fea9d54c1bd0e34181 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#1d953f",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

# %% [markdown]
# # Bar_Bar_markline_custom
# - 【Python数据可视化柱状图AI教程】自定义数据标记线柱状图
# - 自定义标记线的可视化柱状图
# - https://www.zhihu.com/zvideo/1347105488706994176

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_markline_custom"))
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
        markline_opts=opts.MarkLineOpts(
            data=[opts.MarkLineItem(y=80, name="yAxis=80")]
        ),
    )
#     .render("bar_markline_custom.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="40a845316be94a019fda3ad6021da31c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_40a845316be94a019fda3ad6021da31c = echarts.init(
#                     document.getElementById('40a845316be94a019fda3ad6021da31c'), 'white', {renderer: 'canvas'});
#                 var option_40a845316be94a019fda3ad6021da31c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_base
# - 【Python数据可视化柱状图AI教程】标准柱状图
# - 基础标准的可视化柱状图
# - https://www.zhihu.com/zvideo/1347105488706994176

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Lab A", Faker.values())
    .add_yaxis("Lab B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar_base", subtitle="subtitle"))
#     .render("bar_base.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="efe8ce720afe499c85b71700f22519d4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_efe8ce720afe499c85b71700f22519d4 = echarts.init(
#                     document.getElementById('efe8ce720afe499c85b71700f22519d4'), 'white', {renderer: 'canvas'});
#                 var option_efe8ce720afe499c85b71700f22519d4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Bar_Bar_datazoom_both
# - 【Python数据可视化柱状图AI教程】图表内部滑块拖动缩放并显示标记柱状图
# - 可视化图表中内部数据选取伴随X轴数据标记的可视化柱状图
# - https://www.zhihu.com/zvideo/1347105836888657920

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.days_attrs)
    .add_yaxis("Lab A", Faker.days_values, color=Faker.rand_color())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-DataZoom（slider+inside）"),
        datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
    )
#     .render("bar_datazoom_both.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ef30c97c22224dc1918fffc12bb8b438" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ef30c97c22224dc1918fffc12bb8b438 = echarts.init(
#                     document.getElementById('ef30c97c22224dc1918fffc12bb8b438'), 'white', {renderer: 'canvas'});
#                 var option_ef30c97c22224dc1918fffc12bb8b438 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

# %% [markdown]
# # Bar3d_Bar3d_punch_card
# - 【Python数据可视化柱状图AI教程】标准3D柱状图
# - 携带刻度尺可以进行数据高亮选择的3D可视化柱状图
# - https://www.zhihu.com/zvideo/1347106692803596288

# %%
import random
import pyecharts.options as opts
from pyecharts.charts import Bar3D

hours = ["12a","1a","2a","3a","4a","5a","6a","7a","8a","9a","10a","11a","12p","1p","2p","3p","4p","5p","6p","7p","8p","9p","10p","11p",]
days = ["Saturday", "Friday", "Thursday", "Wednesday", "Tuesday", "Monday", "Sunday"]

data = [(i, j, random.randint(0, 12)) for i in range(6) for j in range(24)]
data = [[d[1], d[0], d[2]] for d in data]


c=(
    Bar3D(init_opts=opts.InitOpts(width="900px", height="600px"))
    .add(
        series_name="",
        data=data,
        xaxis3d_opts=opts.Axis3DOpts(type_="category", data=hours),
        yaxis3d_opts=opts.Axis3DOpts(type_="category", data=days),
        zaxis3d_opts=opts.Axis3DOpts(type_="value"),
    )
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(
            max_=20,
            range_color=[
                "#313695",
                "#4575b4",
                "#74add1",
                "#abd9e9",
                "#e0f3f8",
                "#ffffbf",
                "#fee090",
                "#fdae61",
                "#f46d43",
                "#d73027",
                "#a50026",
            ],
        )
    )
#     .render("bar3d_punch_card.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="4086687dc7814603a3b96260b5afdd3d" style="width:900px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_4086687dc7814603a3b96260b5afdd3d = echarts.init(
#                     document.getElementById('4086687dc7814603a3b96260b5afdd3d'), 'white', {renderer: 'canvas'});
#                 var option_4086687dc7814603a3b96260b5afdd3d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
# ...

# %% [markdown]
# # Bar3d_Bar3d_stack
# - 【Python数据可视化柱状图AI教程】堆叠3D柱状图
# - 可以进行数据堆叠效果显示的3D可视化柱状图
# - https://www.zhihu.com/zvideo/1347108068241649664

# %%
import random

from pyecharts import options as opts
from pyecharts.charts import Bar3D

x_data = y_data = list(range(10))


def generate_data():
    data = []
    for j in range(10):
        for k in range(10):
            value = random.randint(0, 9)
            data.append([j, k, value * 2 + 4])
    return data


bar3d = Bar3D()
for _ in range(10):
    bar3d.add(
        "",
        generate_data(),
        shading="lambert",
        xaxis3d_opts=opts.Axis3DOpts(data=x_data, type_="value"),
        yaxis3d_opts=opts.Axis3DOpts(data=y_data, type_="value"),
        zaxis3d_opts=opts.Axis3DOpts(type_="value"),
    )
bar3d.set_global_opts(title_opts=opts.TitleOpts("Bar3d_stack"))
bar3d.set_series_opts(**{"stack": "stack"})
# bar3d.render("bar3d_stack.html")
bar3d.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="2d034da76f254391a02ad684c33c7e53" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_2d034da76f254391a02ad684c33c7e53 = echarts.init(
#                     document.getElementById('2d034da76f254391a02ad684c33c7e53'), 'white', {renderer: 'canvas'});
#                 var option_2d034da76f254391a02ad684c33c7e53 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
# ...
