# %% [markdown]
# # Grid_Grid_overlap_multi_xy_axis
# - 【Python数据可视化组件AI教程】多X、Y轴组合图
# - 多图表合并显示

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line

bar = (
    Bar()
    .add_xaxis(["{}month".format(i) for i in range(1, 13)])
    .add_yaxis(
        "Evaporation",
        [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3],
        yaxis_index=0,
        color="#d14a61",
    )
    .add_yaxis(
        "Precipitation",
        [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3],
        yaxis_index=1,
        color="#5793f3",
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="Evaporation",
            type_="value",
            min_=0,
            max_=250,
            position="right",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#d14a61")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
        )
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            type_="value",
            name="temperature",
            min_=0,
            max_=25,
            position="left",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#675bba")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} °C"),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=1)
            ),
        )
    )
    .set_global_opts(
        yaxis_opts=opts.AxisOpts(
            name="Precipitation",
            min_=0,
            max_=250,
            position="right",
            offset=80,
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#5793f3")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
        ),
        title_opts=opts.TitleOpts(title="Grid-Overlap-More X/Y Demo"),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        legend_opts=opts.LegendOpts(pos_left="25%"),
    )
)

line = (
    Line()
    .add_xaxis(["{}month".format(i) for i in range(1, 13)])
    .add_yaxis(
        "AVG temperature",
        [2.0, 2.2, 3.3, 4.5, 6.3, 10.2, 20.3, 23.4, 23.0, 16.5, 12.0, 6.2],
        yaxis_index=2,
        color="#675bba",
        label_opts=opts.LabelOpts(is_show=False),
    )
)

bar1 = (
    Bar()
    .add_xaxis(["{}month".format(i) for i in range(1, 13)])
    .add_yaxis(
        "Evaporation 1",
        [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3],
        color="#d14a61",
        xaxis_index=1,
        yaxis_index=3,
    )
    .add_yaxis(
        "Precipitation 2",
        [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3],
        color="#5793f3",
        xaxis_index=1,
        yaxis_index=3,
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="Evaporation",
            type_="value",
            min_=0,
            max_=250,
            position="right",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#d14a61")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
        )
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            type_="value",
            name="temperature",
            min_=0,
            max_=25,
            position="left",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#675bba")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} °C"),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=1)
            ),
        )
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(grid_index=1),
        yaxis_opts=opts.AxisOpts(
            name="Precipitation",
            min_=0,
            max_=250,
            position="right",
            offset=80,
            grid_index=1,
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#5793f3")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
        ),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        legend_opts=opts.LegendOpts(pos_left="65%"),
    )
)

line1 = (
    Line()
    .add_xaxis(["{}month".format(i) for i in range(1, 13)])
    .add_yaxis(
        "AVG temperature 1",
        [2.0, 2.2, 3.3, 4.5, 6.3, 10.2, 20.3, 23.4, 23.0, 16.5, 12.0, 6.2],
        color="#675bba",
        label_opts=opts.LabelOpts(is_show=False),
        xaxis_index=1,
        yaxis_index=5,
    )
)

overlap_1 = bar.overlap(line)
overlap_2 = bar1.overlap(line1)

grid = (
    Grid(init_opts=opts.InitOpts(width="900px", height="600px"))
    .add(
        overlap_1, grid_opts=opts.GridOpts(pos_right="58%"), is_control_axis_index=True
    )
    .add(overlap_2, grid_opts=opts.GridOpts(pos_left="58%"), is_control_axis_index=True)
#     .render("grid_overlap_multi_xy_axis.html")
)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="10a490774f274565a49b08568581c9bc" style="width:900px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_10a490774f274565a49b08568581c9bc = echarts.init(
#                     document.getElementById('10a490774f274565a49b08568581c9bc'), 'white', {renderer: 'canvas'});
#                 var option_10a490774f274565a49b08568581c9bc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#5793f3",
#         "#d14a61",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Evaporation",
#             "yAxisIndex": 0,
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Precipitation",
#             "yAxisIndex": 1,
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "AVG temperature",
#             "connectNulls": false,
#             "yAxisIndex": 2,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1month",
#                     2.0
#                 ],
#                 [
#                     "2month",
#                     2.2
#                 ],
#                 [
#                     "3month",
#                     3.3
#                 ],
#                 [
#                     "4month",
#                     4.5
#                 ],
#                 [
#                     "5month",
#                     6.3
#                 ],
#                 [
#                     "6month",
#                     10.2
#                 ],
#                 [
#                     "7month",
#                     20.3
#                 ],
#                 [
#                     "8month",
#                     23.4
#                 ],
#                 [
#                     "9month",
#                     23.0
#                 ],
#                 [
#                     "10month",
#                     16.5
#                 ],
#                 [
#                     "11month",
#                     12.0
#                 ],
#                 [
#                     "12month",
#                     6.2
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "bar",
#             "name": "Evaporation 1",
#             "xAxisIndex": 1,
#             "yAxisIndex": 3,
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Precipitation 2",
#             "xAxisIndex": 1,
#             "yAxisIndex": 3,
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "AVG temperature 1",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 5,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1month",
#                     2.0
#                 ],
#                 [
#                     "2month",
#                     2.2
#                 ],
#                 [
#                     "3month",
#                     3.3
#                 ],
#                 [
#                     "4month",
#                     4.5
#                 ],
#                 [
#                     "5month",
#                     6.3
#                 ],
#                 [
#                     "6month",
#                     10.2
#                 ],
#                 [
#                     "7month",
#                     20.3
#                 ],
#                 [
#                     "8month",
#                     23.4
#                 ],
#                 [
#                     "9month",
#                     23.0
#                 ],
#                 [
#                     "10month",
#                     16.5
#                 ],
#                 [
#                     "11month",
#                     12.0
#                 ],
#                 [
#                     "12month",
#                     6.2
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Evaporation",
#                 "Precipitation",
#                 "AVG temperature"
#             ],
#             "selected": {
#                 "Evaporation": true,
#                 "Precipitation": true
#             },
#             "show": true,
#             "left": "25%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [

# %% [markdown]
# # Grid_Grid_multi_yaxis
# - 【Python数据可视化组件AI教程】多Y轴组合图
# - 多个Y轴刻度组合图

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line

x_data = ["{}month".format(i) for i in range(1, 13)]
bar = (
    Bar()
    .add_xaxis(x_data)
    .add_yaxis(
        "Evaporation",
        [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3],
        yaxis_index=0,
        color="#d14a61",
    )
    .add_yaxis(
        "Precipitation",
        [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3],
        yaxis_index=1,
        color="#5793f3",
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="Evaporation",
            type_="value",
            min_=0,
            max_=250,
            position="right",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#d14a61")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
        )
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            type_="value",
            name="temperature",
            min_=0,
            max_=25,
            position="left",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#675bba")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} °C"),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=1)
            ),
        )
    )
    .set_global_opts(
        yaxis_opts=opts.AxisOpts(
            name="Precipitation",
            min_=0,
            max_=250,
            position="right",
            offset=80,
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#5793f3")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
        ),
        title_opts=opts.TitleOpts(title="Grid-多 Y 轴示例"),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
    )
)

line = (
    Line()
    .add_xaxis(x_data)
    .add_yaxis(
        "AVG  temperature",
        [2.0, 2.2, 3.3, 4.5, 6.3, 10.2, 20.3, 23.4, 23.0, 16.5, 12.0, 6.2],
        yaxis_index=2,
        color="#675bba",
        label_opts=opts.LabelOpts(is_show=False),
    )
)

bar.overlap(line)
grid = Grid()
grid.add(bar, opts.GridOpts(pos_left="5%", pos_right="20%"), is_control_axis_index=True)
# grid.render("grid_multi_yaxis.html")
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="880edfe121914d55a3b7e6fbb80cce90" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_880edfe121914d55a3b7e6fbb80cce90 = echarts.init(
#                     document.getElementById('880edfe121914d55a3b7e6fbb80cce90'), 'white', {renderer: 'canvas'});
#                 var option_880edfe121914d55a3b7e6fbb80cce90 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#5793f3",
#         "#d14a61",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Evaporation",
#             "yAxisIndex": 0,
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Precipitation",
#             "yAxisIndex": 1,
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "AVG  temperature",
#             "connectNulls": false,
#             "yAxisIndex": 2,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1month",
#                     2.0
#                 ],
#                 [
#                     "2month",
#                     2.2
#                 ],
#                 [
#                     "3month",
#                     3.3
#                 ],
#                 [
#                     "4month",
#                     4.5
#                 ],
#                 [
#                     "5month",
#                     6.3
#                 ],
#                 [
#                     "6month",
#                     10.2
#                 ],
#                 [
#                     "7month",
#                     20.3
#                 ],
#                 [
#                     "8month",
#                     23.4
#                 ],
#                 [
#                     "9month",
#                     23.0
#                 ],
#                 [
#                     "10month",
#                     16.5
#                 ],
#                 [
#                     "11month",
#                     12.0
#                 ],
#                 [
#                     "12month",
#                     6.2
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Evaporation",
#                 "Precipitation",
#                 "AVG  temperature"
#             ],
#             "selected": {
#                 "Evaporation": true,
#                 "Precipitation": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1month",
#                 "2month",
#                 "3month",
#                 "4month",
#                 "5month",
#                 "6month",
#                 "7month",
#                 "8month",
#                 "9month",
#                 "10month",
#                 "11month",
#                 "12month"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "Precipitation",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#5793f3"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} ml"
#             },
#             "inverse": false,
#             "position": "right",
#             "offset": 80,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 250,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "value",
#             "name": "Evaporation",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#d14a61"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,

# %% [markdown]
# # Grid_Grid_vertical
# - 【Python数据可视化组件AI教程】垂直多表组合图
# - 折线图、柱状图组合图表

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line
from pyecharts.faker import Faker

bar = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Label A", Faker.values())
    .add_yaxis("Label B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Grid-Bar"))
)
line = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("Label A", Faker.values())
    .add_yaxis("Label B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Grid-Line", pos_top="48%"),
        legend_opts=opts.LegendOpts(pos_top="48%"),
    )
)

grid = (
    Grid()
    .add(bar, grid_opts=opts.GridOpts(pos_bottom="60%"))
    .add(line, grid_opts=opts.GridOpts(pos_top="60%"))
#     .render("grid_vertical.html")
)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="29cf340dbc2f48589705930b7a28428e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_29cf340dbc2f48589705930b7a28428e = echarts.init(
#                     document.getElementById('29cf340dbc2f48589705930b7a28428e'), 'white', {renderer: 'canvas'});
#                 var option_29cf340dbc2f48589705930b7a28428e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Label A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 140,
#                 57,
#                 145,
#                 110,
#                 62,
#                 96,
#                 32
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Label B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 106,
#                 23,
#                 31,
#                 42,
#                 146,
#                 41,
#                 76
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "Label A",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     118
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     27
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     74
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     104
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     134
#                 ],
#                 [
#                     "VIVO",
#                     100
#                 ],
#                 [
#                     "OPPO",
#                     64
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "Label B",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     102
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     144
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     44
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     86
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     142
#                 ],
#                 [
#                     "VIVO",
#                     94
#                 ],
#                 [
#                     "OPPO",
#                     112
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Label A",
#                 "Label B"
#             ],
#             "selected": {
#                 "Label A": true,
#                 "Label B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [
#                 "Label A",
#                 "Label B"
#             ],
#             "selected": {
#                 "Label A": true,
#                 "Label B": true
#             },
#             "show": true,
#             "top": "48%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 1,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",

# %% [markdown]
# # Grid_Grid_geo_bar
# - 【Python数据可视化组件AI教程】内部镶嵌组合图
# - 柱状图、地理图组合图表

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Geo, Grid
from pyecharts.faker import Faker

bar = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("Label A", Faker.values())
    .add_yaxis("Label B", Faker.values())
    .set_global_opts(legend_opts=opts.LegendOpts(pos_left="20%"))
)
geo = (
    Geo()
    .add_schema(maptype="china")
    .add("China Map", [list(z) for z in zip(Faker.provinces, Faker.values())])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="Grid-Geo-Bar"),
    )
)

grid = (
    Grid()
    .add(bar, grid_opts=opts.GridOpts(pos_top="50%", pos_right="75%"))
    .add(geo, grid_opts=opts.GridOpts(pos_left="60%"))
#     .render("grid_geo_bar.html")
)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="129d82452a68479890ff43c957973d19" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_129d82452a68479890ff43c957973d19 = echarts.init(
#                     document.getElementById('129d82452a68479890ff43c957973d19'), 'white', {renderer: 'canvas'});
#                 var option_129d82452a68479890ff43c957973d19 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Label A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 40,
#                 65,
#                 127,
#                 139,
#                 20,
#                 46,
#                 95
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Label B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 63,
#                 28,
#                 38,
#                 73,
#                 81,
#                 114,
#                 115
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "China Map",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         89
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         94
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         138
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         94
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         77
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         63
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         51
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "xAxisIndex": 1,
#             "yAxisIndex": 1
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Label A",
#                 "Label B"
#             ],
#             "selected": {
#                 "Label A": true,
#                 "Label B": true
#             },
#             "show": true,
#             "left": "20%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [
#                 "China Map"
#             ],
#             "selected": {
#                 "China Map": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         },
#         {
#             "text": "Grid-Geo-Bar",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "grid": [
#         {
#             "top": "50%",
#             "right": "75%",
#             "containLabel": false
#         },
#         {
#             "left": "60%",
#             "containLabel": false
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_129d82452a68479890ff43c957973d19.setOption(option_129d82452a68479890ff43c957973d19);
#         });
#     </script>

# %% [markdown]
# # Grid_Grid_horizontal
# - 【Python数据可视化组件AI教程】水平组合图
# - 折线图、散点图组合图

# %%
from pyecharts import options as opts
from pyecharts.charts import Grid, Line, Scatter
from pyecharts.faker import Faker

scatter = (
    Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("Label A", Faker.values())
    .add_yaxis("Label B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Grid-Scatter"),
        legend_opts=opts.LegendOpts(pos_left="20%"),
    )
)
line = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("Label A", Faker.values())
    .add_yaxis("Label B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Grid-Line", pos_right="5%"),
        legend_opts=opts.LegendOpts(pos_right="20%"),
    )
)

grid = (
    Grid()
    .add(scatter, grid_opts=opts.GridOpts(pos_left="55%"))
    .add(line, grid_opts=opts.GridOpts(pos_right="55%"))
#     .render("grid_horizontal.html")
)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d5b985acf84e4a6abeb1a08163165539" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d5b985acf84e4a6abeb1a08163165539 = echarts.init(
#                     document.getElementById('d5b985acf84e4a6abeb1a08163165539'), 'white', {renderer: 'canvas'});
#                 var option_d5b985acf84e4a6abeb1a08163165539 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "Label A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     58
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     106
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     87
#                 ],
#                 [
#                     "\u5468\u56db",
#                     112
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     28
#                 ],
#                 [
#                     "\u5468\u516d",
#                     88
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     64
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "Label B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     46
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     128
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     62
#                 ],
#                 [
#                     "\u5468\u56db",
#                     84
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     80
#                 ],
#                 [
#                     "\u5468\u516d",
#                     144
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     53
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "Label A",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u53ef\u4e50",
#                     136
#                 ],
#                 [
#                     "\u96ea\u78a7",
#                     43
#                 ],
#                 [
#                     "\u6a59\u6c41",
#                     61
#                 ],
#                 [
#                     "\u7eff\u8336",
#                     119
#                 ],
#                 [
#                     "\u5976\u8336",
#                     135
#                 ],
#                 [
#                     "\u767e\u5a01",
#                     135
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     81
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "Label B",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u53ef\u4e50",
#                     149
#                 ],
#                 [
#                     "\u96ea\u78a7",
#                     95
#                 ],
#                 [
#                     "\u6a59\u6c41",
#                     100
#                 ],
#                 [
#                     "\u7eff\u8336",
#                     133
#                 ],
#                 [
#                     "\u5976\u8336",
#                     91
#                 ],
#                 [
#                     "\u767e\u5a01",
#                     50
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     41
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Label A",
#                 "Label B"
#             ],
#             "selected": {
#                 "Label A": true,
#                 "Label B": true
#             },
#             "show": true,
#             "left": "20%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [
#                 "Label A",
#                 "Label B"
#             ],
#             "selected": {
#                 "Label A": true,
#                 "Label B": true
#             },
#             "show": true,
#             "right": "20%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
